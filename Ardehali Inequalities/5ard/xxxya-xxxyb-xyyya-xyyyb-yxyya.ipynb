# %%
from qiskit import *
qr1 = QuantumRegister(5)
cr1 = ClassicalRegister(5)
xxxya = QuantumCircuit(qr1, cr1)
# %matplotlib inline
xxxya.h(qr1[0])
xxxya.h(qr1[1])
xxxya.h(qr1[3])
xxxya.h(qr1[4])
xxxya.cx(qr1[1],qr1[2])
xxxya.h(qr1[1])
xxxya.cx(qr1[3],qr1[2])
xxxya.h(qr1[3])
xxxya.cx(qr1[4],qr1[2])
xxxya.cx(qr1[0],qr1[2])
xxxya.h(qr1[0])
xxxya.h(qr1[2])
xxxya.h(qr1[4])

xxxya.barrier(qr1)

xxxya.h(qr1[0])
xxxya.h(qr1[1])
xxxya.h(qr1[2])
xxxya.sdg(qr1[3])
xxxya.h(qr1[3])
xxxya.tdg(qr1[4])
xxxya.h(qr1[4])
xxxya.measure(qr1, cr1)
xxxya.draw(output='mpl')

# %%
qr2 = QuantumRegister(5)
cr2 = ClassicalRegister(5)
xxxyb = QuantumCircuit(qr2, cr2)
# %matplotlib inline
xxxyb.h(qr2[0])
xxxyb.h(qr2[1])
xxxyb.h(qr2[3])
xxxyb.h(qr2[4])
xxxyb.cx(qr2[1],qr2[2])
xxxyb.h(qr2[1])
xxxyb.cx(qr2[3],qr2[2])
xxxyb.h(qr2[3])
xxxyb.cx(qr2[4],qr2[2])
xxxyb.cx(qr2[0],qr2[2])
xxxyb.h(qr2[0])
xxxyb.h(qr2[2])
xxxyb.h(qr2[4])

xxxyb.barrier(qr2)


xxxyb.h(qr2[0])
xxxyb.h(qr2[1])
xxxyb.h(qr2[2])
xxxyb.sdg(qr2[3])
xxxyb.h(qr2[3])
xxxyb.t(qr2[4])
xxxyb.h(qr2[4])
xxxyb.measure(qr2, cr2)
xxxyb.draw(output='mpl')

# %%
qr3 = QuantumRegister(5)
cr3 = ClassicalRegister(5)
xyyya = QuantumCircuit(qr3, cr3)
# %matplotlib inline
xyyya.h(qr3[0])
xyyya.h(qr3[1])
xyyya.h(qr3[3])
xyyya.h(qr3[4])
xyyya.cx(qr3[1],qr3[2])
xyyya.h(qr3[1])
xyyya.cx(qr3[3],qr3[2])
xyyya.h(qr3[3])
xyyya.cx(qr3[4],qr3[2])
xyyya.cx(qr3[0],qr3[2])
xyyya.h(qr3[0])
xyyya.h(qr3[2])
xyyya.h(qr3[4])

xyyya.barrier(qr3)

xyyya.h(qr3[0])
xyyya.sdg(qr3[1])
xyyya.h(qr3[1])
xyyya.sdg(qr3[2])
xyyya.h(qr3[2])
xyyya.sdg(qr3[3])
xyyya.h(qr3[3])
xyyya.tdg(qr3[4])
xyyya.h(qr3[4])
xyyya.measure(qr3, cr3)
xyyya.draw(output='mpl')

# %%
qr4 = QuantumRegister(5)
cr4 = ClassicalRegister(5)
xyyyb = QuantumCircuit(qr4, cr4)
# %matplotlib inline
xyyyb.h(qr4[0])
xyyyb.h(qr4[1])
xyyyb.h(qr4[3])
xyyyb.h(qr4[4])
xyyyb.cx(qr4[1],qr4[2])
xyyyb.h(qr4[1])
xyyyb.cx(qr4[3],qr4[2])
xyyyb.h(qr4[3])
xyyyb.cx(qr4[4],qr4[2])
xyyyb.cx(qr4[0],qr4[2])
xyyyb.h(qr4[0])
xyyyb.h(qr4[2])
xyyyb.h(qr4[4])

xyyyb.barrier(qr4)

xyyyb.h(qr4[0])
xyyyb.sdg(qr4[1])
xyyyb.h(qr4[1])
xyyyb.sdg(qr4[2])
xyyyb.h(qr4[2])
xyyyb.sdg(qr4[3])
xyyyb.h(qr4[3])
xyyyb.t(qr4[4])
xyyyb.h(qr4[4])
xyyyb.measure(qr4, cr4)
xyyyb.draw(output='mpl')

# %%
qr5 = QuantumRegister(5)
cr5 = ClassicalRegister(5)
yxyya = QuantumCircuit(qr5, cr5)
# %matplotlib inline
yxyya.h(qr5[0])
yxyya.h(qr5[1])
yxyya.h(qr5[3])
yxyya.h(qr5[4])
yxyya.cx(qr5[1],qr5[2])
yxyya.h(qr5[1])
yxyya.cx(qr5[3],qr5[2])
yxyya.h(qr5[3])
yxyya.cx(qr5[4],qr5[2])
yxyya.cx(qr5[0],qr5[2])
yxyya.h(qr5[0])
yxyya.h(qr5[2])
yxyya.h(qr5[4])

yxyya.barrier(qr5)

yxyya.sdg(qr5[0])
yxyya.h(qr5[0])
yxyya.h(qr5[1])
yxyya.sdg(qr5[2])
yxyya.h(qr5[2])
yxyya.sdg(qr5[3])
yxyya.h(qr5[3])
yxyya.tdg(qr5[4])
yxyya.h(qr5[4])
yxyya.measure(qr5, cr5)
yxyya.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_athens')
job1 = execute(xxxya, backend=qcomp,shots = 8192)
job2 = execute(xxxyb, backend=qcomp,shots = 8192)
job3 = execute(xyyya, backend=qcomp,shots = 8192)
job4 = execute(xyyyb, backend=qcomp,shots = 8192)
job5 = execute(yxyya, backend=qcomp,shots = 8192)
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job1)
job_monitor(job2)
job_monitor(job3)
job_monitor(job4)
job_monitor(job5)
# Out:
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run

# %%
result1 = job1.result()
result2 = job2.result()
result3 = job3.result()
result4 = job4.result()
result5 = job5.result()
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result1.get_counts(xxxya))

# %%
plot_histogram(result2.get_counts(xxxyb))

# %%
plot_histogram(result3.get_counts(xyyya))

# %%
plot_histogram(result4.get_counts(xyyyb))

# %%
plot_histogram(result5.get_counts(yxyya))

# %%
p1= ((result1.get_counts(xxxya)['00000']
     +result1.get_counts(xxxya)['00011']
     +result1.get_counts(xxxya)['00101']
     +result1.get_counts(xxxya)['00110']
     +result1.get_counts(xxxya)['01001']
     +result1.get_counts(xxxya)['01010']
     +result1.get_counts(xxxya)['01100']
     +result1.get_counts(xxxya)['01111']
     +result1.get_counts(xxxya)['10001']
     +result1.get_counts(xxxya)['10010']
     +result1.get_counts(xxxya)['10100']
     +result1.get_counts(xxxya)['10111']
     +result1.get_counts(xxxya)['11000']
     +result1.get_counts(xxxya)['11011']
     +result1.get_counts(xxxya)['11101']
     +result1.get_counts(xxxya)['11110']
       
    -(result1.get_counts(xxxya)['00001']
     +result1.get_counts(xxxya)['00010']
     +result1.get_counts(xxxya)['00100']
     +result1.get_counts(xxxya)['00111']
     +result1.get_counts(xxxya)['01000']
     +result1.get_counts(xxxya)['01011']
     +result1.get_counts(xxxya)['01101']
     +result1.get_counts(xxxya)['01110']
     +result1.get_counts(xxxya)['10000']
     +result1.get_counts(xxxya)['10011']
     +result1.get_counts(xxxya)['10101']
     +result1.get_counts(xxxya)['10110']
     +result1.get_counts(xxxya)['11001']
     +result1.get_counts(xxxya)['11010']
     +result1.get_counts(xxxya)['11100']
     +result1.get_counts(xxxya)['11111'])
      )/8192)
print(p1)
# Out:
# -0.6201171875

# %%
p2=((result2.get_counts(xxxyb)['00000']
     +result2.get_counts(xxxyb)['00011']
     +result2.get_counts(xxxyb)['00101']
     +result2.get_counts(xxxyb)['00110']
     +result2.get_counts(xxxyb)['01001']
     +result2.get_counts(xxxyb)['01010']
     +result2.get_counts(xxxyb)['01100']
     +result2.get_counts(xxxyb)['01111']
     +result2.get_counts(xxxyb)['10001']
     +result2.get_counts(xxxyb)['10010']
     +result2.get_counts(xxxyb)['10100']
     +result2.get_counts(xxxyb)['10111']
     +result2.get_counts(xxxyb)['11000']
     +result2.get_counts(xxxyb)['11011']
     +result2.get_counts(xxxyb)['11101']
     +result2.get_counts(xxxyb)['11110']
       
    -(result2.get_counts(xxxyb)['00001']
     +result2.get_counts(xxxyb)['00010']
     +result2.get_counts(xxxyb)['00100']
     +result2.get_counts(xxxyb)['00111']
     +result2.get_counts(xxxyb)['01000']
     +result2.get_counts(xxxyb)['01011']
     +result2.get_counts(xxxyb)['01101']
     +result2.get_counts(xxxyb)['01110']
     +result2.get_counts(xxxyb)['10000']
     +result2.get_counts(xxxyb)['10011']
     +result2.get_counts(xxxyb)['10101']
     +result2.get_counts(xxxyb)['10110']
     +result2.get_counts(xxxyb)['11001']
     +result2.get_counts(xxxyb)['11010']
     +result2.get_counts(xxxyb)['11100']
     +result2.get_counts(xxxyb)['11111'])
      )/8192)
print(p2)
# Out:
# 0.34716796875

# %%
p3=((result3.get_counts(xyyya)['00000']
     +result3.get_counts(xyyya)['00011']
     +result3.get_counts(xyyya)['00101']
     +result3.get_counts(xyyya)['00110']
     +result3.get_counts(xyyya)['01001']
     +result3.get_counts(xyyya)['01010']
     +result3.get_counts(xyyya)['01100']
     +result3.get_counts(xyyya)['01111']
     +result3.get_counts(xyyya)['10001']
     +result3.get_counts(xyyya)['10010']
     +result3.get_counts(xyyya)['10100']
     +result3.get_counts(xyyya)['10111']
     +result3.get_counts(xyyya)['11000']
     +result3.get_counts(xyyya)['11011']
     +result3.get_counts(xyyya)['11101']
     +result3.get_counts(xyyya)['11110']
       
    -(result3.get_counts(xyyya)['00001']
     +result3.get_counts(xyyya)['00010']
     +result3.get_counts(xyyya)['00100']
     +result3.get_counts(xyyya)['00111']
     +result3.get_counts(xyyya)['01000']
     +result3.get_counts(xyyya)['01011']
     +result3.get_counts(xyyya)['01101']
     +result3.get_counts(xyyya)['01110']
     +result3.get_counts(xyyya)['10000']
     +result3.get_counts(xyyya)['10011']
     +result3.get_counts(xyyya)['10101']
     +result3.get_counts(xyyya)['10110']
     +result3.get_counts(xyyya)['11001']
     +result3.get_counts(xyyya)['11010']
     +result3.get_counts(xyyya)['11100']
     +result3.get_counts(xyyya)['11111'])
      )/8192)
print(p3)
# Out:
# 0.60302734375

# %%
p4=((result4.get_counts(xyyyb)['00000']
     +result4.get_counts(xyyyb)['00011']
     +result4.get_counts(xyyyb)['00101']
     +result4.get_counts(xyyyb)['00110']
     +result4.get_counts(xyyyb)['01001']
     +result4.get_counts(xyyyb)['01010']
     +result4.get_counts(xyyyb)['01100']
     +result4.get_counts(xyyyb)['01111']
     +result4.get_counts(xyyyb)['10001']
     +result4.get_counts(xyyyb)['10010']
     +result4.get_counts(xyyyb)['10100']
     +result4.get_counts(xyyyb)['10111']
     +result4.get_counts(xyyyb)['11000']
     +result4.get_counts(xyyyb)['11011']
     +result4.get_counts(xyyyb)['11101']
     +result4.get_counts(xyyyb)['11110']
       
    -(result4.get_counts(xyyyb)['00001']
     +result4.get_counts(xyyyb)['00010']
     +result4.get_counts(xyyyb)['00100']
     +result4.get_counts(xyyyb)['00111']
     +result4.get_counts(xyyyb)['01000']
     +result4.get_counts(xyyyb)['01011']
     +result4.get_counts(xyyyb)['01101']
     +result4.get_counts(xyyyb)['01110']
     +result4.get_counts(xyyyb)['10000']
     +result4.get_counts(xyyyb)['10011']
     +result4.get_counts(xyyyb)['10101']
     +result4.get_counts(xyyyb)['10110']
     +result4.get_counts(xyyyb)['11001']
     +result4.get_counts(xyyyb)['11010']
     +result4.get_counts(xyyyb)['11100']
     +result4.get_counts(xyyyb)['11111'])
      )/8192)
print(p4)
# Out:
# -0.32421875

# %%
p5=((result5.get_counts(yxyya)['00000']
     +result5.get_counts(yxyya)['00011']
     +result5.get_counts(yxyya)['00101']
     +result5.get_counts(yxyya)['00110']
     +result5.get_counts(yxyya)['01001']
     +result5.get_counts(yxyya)['01010']
     +result5.get_counts(yxyya)['01100']
     +result5.get_counts(yxyya)['01111']
     +result5.get_counts(yxyya)['10001']
     +result5.get_counts(yxyya)['10010']
     +result5.get_counts(yxyya)['10100']
     +result5.get_counts(yxyya)['10111']
     +result5.get_counts(yxyya)['11000']
     +result5.get_counts(yxyya)['11011']
     +result5.get_counts(yxyya)['11101']
     +result5.get_counts(yxyya)['11110']
       
    -(result5.get_counts(yxyya)['00001']
     +result5.get_counts(yxyya)['00010']
     +result5.get_counts(yxyya)['00100']
     +result5.get_counts(yxyya)['00111']
     +result5.get_counts(yxyya)['01000']
     +result5.get_counts(yxyya)['01011']
     +result5.get_counts(yxyya)['01101']
     +result5.get_counts(yxyya)['01110']
     +result5.get_counts(yxyya)['10000']
     +result5.get_counts(yxyya)['10011']
     +result5.get_counts(yxyya)['10101']
     +result5.get_counts(yxyya)['10110']
     +result5.get_counts(yxyya)['11001']
     +result5.get_counts(yxyya)['11010']
     +result5.get_counts(yxyya)['11100']
     +result5.get_counts(yxyya)['11111'])
      )/8192)
print(p5)
# Out:
# 0.5390625

# %%
print(abs(p1)+abs(p2)+abs(p3)+abs(p4)+abs(p5))
# Out:
# 2.43359375
