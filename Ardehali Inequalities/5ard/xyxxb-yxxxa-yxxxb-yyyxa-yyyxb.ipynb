# %%
from qiskit import *
qr1 = QuantumRegister(5)
cr1 = ClassicalRegister(5)
xyxxb = QuantumCircuit(qr1, cr1)
# %matplotlib inline
xyxxb.h(qr1[0])
xyxxb.h(qr1[1])
xyxxb.h(qr1[3])
xyxxb.h(qr1[4])
xyxxb.cx(qr1[1],qr1[2])
xyxxb.h(qr1[1])
xyxxb.cx(qr1[3],qr1[2])
xyxxb.h(qr1[3])
xyxxb.cx(qr1[4],qr1[2])
xyxxb.cx(qr1[0],qr1[2])
xyxxb.h(qr1[0])
xyxxb.h(qr1[2])
xyxxb.h(qr1[4])

xyxxb.barrier(qr1)

xyxxb.h(qr1[0])
xyxxb.sdg(qr1[1])
xyxxb.h(qr1[1])
xyxxb.h(qr1[2])
xyxxb.h(qr1[3])
xyxxb.t(qr1[4])
xyxxb.h(qr1[4])
xyxxb.measure(qr1, cr1)
xyxxb.draw(output='mpl')

# %%
qr2 = QuantumRegister(5)
cr2 = ClassicalRegister(5)
yxxxa = QuantumCircuit(qr2, cr2)
# %matplotlib inline
yxxxa.h(qr2[0])
yxxxa.h(qr2[1])
yxxxa.h(qr2[3])
yxxxa.h(qr2[4])
yxxxa.cx(qr2[1],qr2[2])
yxxxa.h(qr2[1])
yxxxa.cx(qr2[3],qr2[2])
yxxxa.h(qr2[3])
yxxxa.cx(qr2[4],qr2[2])
yxxxa.cx(qr2[0],qr2[2])
yxxxa.h(qr2[0])
yxxxa.h(qr2[2])
yxxxa.h(qr2[4])

yxxxa.barrier(qr2)

yxxxa.sdg(qr2[0])
yxxxa.h(qr2[0])
yxxxa.h(qr2[1])
yxxxa.h(qr2[2])
yxxxa.h(qr2[3])
yxxxa.tdg(qr2[4])
yxxxa.h(qr2[4])
yxxxa.measure(qr2, cr2)
yxxxa.draw(output='mpl')

# %%
qr3 = QuantumRegister(5)
cr3 = ClassicalRegister(5)
yxxxb = QuantumCircuit(qr3, cr3)
# %matplotlib inline
yxxxb.h(qr3[0])
yxxxb.h(qr3[1])
yxxxb.h(qr3[3])
yxxxb.h(qr3[4])
yxxxb.cx(qr3[1],qr3[2])
yxxxb.h(qr3[1])
yxxxb.cx(qr3[3],qr3[2])
yxxxb.h(qr3[3])
yxxxb.cx(qr3[4],qr3[2])
yxxxb.cx(qr3[0],qr3[2])
yxxxb.h(qr3[0])
yxxxb.h(qr3[2])
yxxxb.h(qr3[4])

yxxxb.barrier(qr3)

yxxxb.sdg(qr3[0])
yxxxb.h(qr3[0])
yxxxb.h(qr3[1])
yxxxb.h(qr3[2])
yxxxb.h(qr3[3])
yxxxb.t(qr3[4])
yxxxb.h(qr3[4])
yxxxb.measure(qr3, cr3)
yxxxb.draw(output='mpl')

# %%
qr4 = QuantumRegister(5)
cr4 = ClassicalRegister(5)
yyyxa = QuantumCircuit(qr4, cr4)
# %matplotlib inline
yyyxa.h(qr4[0])
yyyxa.h(qr4[1])
yyyxa.h(qr4[3])
yyyxa.h(qr4[4])
yyyxa.cx(qr4[1],qr4[2])
yyyxa.h(qr4[1])
yyyxa.cx(qr4[3],qr4[2])
yyyxa.h(qr4[3])
yyyxa.cx(qr4[4],qr4[2])
yyyxa.cx(qr4[0],qr4[2])
yyyxa.h(qr4[0])
yyyxa.h(qr4[2])
yyyxa.h(qr4[4])

yyyxa.barrier(qr4)

yyyxa.sdg(qr4[0])
yyyxa.h(qr4[0])
yyyxa.sdg(qr4[1])
yyyxa.h(qr4[1])
yyyxa.sdg(qr4[2])
yyyxa.h(qr4[2])
yyyxa.h(qr4[3])
yyyxa.tdg(qr4[4])
yyyxa.h(qr4[4])
yyyxa.measure(qr4, cr4)
yyyxa.draw(output='mpl')

# %%
qr5 = QuantumRegister(5)
cr5 = ClassicalRegister(5)
yyyxb = QuantumCircuit(qr5, cr5)
# %matplotlib inline
yyyxb.h(qr5[0])
yyyxb.h(qr5[1])
yyyxb.h(qr5[3])
yyyxb.h(qr5[4])
yyyxb.cx(qr5[1],qr5[2])
yyyxb.h(qr5[1])
yyyxb.cx(qr5[3],qr5[2])
yyyxb.h(qr5[3])
yyyxb.cx(qr5[4],qr5[2])
yyyxb.cx(qr5[0],qr5[2])
yyyxb.h(qr5[0])
yyyxb.h(qr5[2])
yyyxb.h(qr5[4])

yyyxb.barrier(qr5)

yyyxb.sdg(qr5[0])
yyyxb.h(qr5[0])
yyyxb.sdg(qr5[1])
yyyxb.h(qr5[1])
yyyxb.sdg(qr5[2])
yyyxb.h(qr5[2])
yyyxb.h(qr5[3])
yyyxb.t(qr5[4])
yyyxb.h(qr5[4])
yyyxb.measure(qr5, cr5)
yyyxb.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_athens')
job1 = execute(xyxxb, backend=qcomp,shots = 8192)
job2 = execute(yxxxa, backend=qcomp,shots = 8192)
job3 = execute(yxxxb, backend=qcomp,shots = 8192)
job4 = execute(yyyxa, backend=qcomp,shots = 8192)
job5 = execute(yyyxb, backend=qcomp,shots = 8192)
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job1)
job_monitor(job2)
job_monitor(job3)
job_monitor(job4)
job_monitor(job5)
# Out:
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run

# %%
result1 = job1.result()
result2 = job2.result()
result3 = job3.result()
result4 = job4.result()
result5 = job5.result()
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result1.get_counts(xyxxb))

# %%
plot_histogram(result2.get_counts(yxxxa))

# %%
plot_histogram(result3.get_counts(yxxxb))

# %%
plot_histogram(result4.get_counts(yyyxa))

# %%
plot_histogram(result5.get_counts(yyyxb))

# %%
p1= ((result1.get_counts(xyxxb)['00000']
     +result1.get_counts(xyxxb)['00011']
     +result1.get_counts(xyxxb)['00101']
     +result1.get_counts(xyxxb)['00110']
     +result1.get_counts(xyxxb)['01001']
     +result1.get_counts(xyxxb)['01010']
     +result1.get_counts(xyxxb)['01100']
     +result1.get_counts(xyxxb)['01111']
     +result1.get_counts(xyxxb)['10001']
     +result1.get_counts(xyxxb)['10010']
     +result1.get_counts(xyxxb)['10100']
     +result1.get_counts(xyxxb)['10111']
     +result1.get_counts(xyxxb)['11000']
     +result1.get_counts(xyxxb)['11011']
     +result1.get_counts(xyxxb)['11101']
     +result1.get_counts(xyxxb)['11110']
       
    -(result1.get_counts(xyxxb)['00001']
     +result1.get_counts(xyxxb)['00010']
     +result1.get_counts(xyxxb)['00100']
     +result1.get_counts(xyxxb)['00111']
     +result1.get_counts(xyxxb)['01000']
     +result1.get_counts(xyxxb)['01011']
     +result1.get_counts(xyxxb)['01101']
     +result1.get_counts(xyxxb)['01110']
     +result1.get_counts(xyxxb)['10000']
     +result1.get_counts(xyxxb)['10011']
     +result1.get_counts(xyxxb)['10101']
     +result1.get_counts(xyxxb)['10110']
     +result1.get_counts(xyxxb)['11001']
     +result1.get_counts(xyxxb)['11010']
     +result1.get_counts(xyxxb)['11100']
     +result1.get_counts(xyxxb)['11111'])
      )/8192)
print(p1)
# Out:
# 0.40478515625

# %%
p2=((result2.get_counts(yxxxa)['00000']
     +result2.get_counts(yxxxa)['00011']
     +result2.get_counts(yxxxa)['00101']
     +result2.get_counts(yxxxa)['00110']
     +result2.get_counts(yxxxa)['01001']
     +result2.get_counts(yxxxa)['01010']
     +result2.get_counts(yxxxa)['01100']
     +result2.get_counts(yxxxa)['01111']
     +result2.get_counts(yxxxa)['10001']
     +result2.get_counts(yxxxa)['10010']
     +result2.get_counts(yxxxa)['10100']
     +result2.get_counts(yxxxa)['10111']
     +result2.get_counts(yxxxa)['11000']
     +result2.get_counts(yxxxa)['11011']
     +result2.get_counts(yxxxa)['11101']
     +result2.get_counts(yxxxa)['11110']
       
    -(result2.get_counts(yxxxa)['00001']
     +result2.get_counts(yxxxa)['00010']
     +result2.get_counts(yxxxa)['00100']
     +result2.get_counts(yxxxa)['00111']
     +result2.get_counts(yxxxa)['01000']
     +result2.get_counts(yxxxa)['01011']
     +result2.get_counts(yxxxa)['01101']
     +result2.get_counts(yxxxa)['01110']
     +result2.get_counts(yxxxa)['10000']
     +result2.get_counts(yxxxa)['10011']
     +result2.get_counts(yxxxa)['10101']
     +result2.get_counts(yxxxa)['10110']
     +result2.get_counts(yxxxa)['11001']
     +result2.get_counts(yxxxa)['11010']
     +result2.get_counts(yxxxa)['11100']
     +result2.get_counts(yxxxa)['11111'])
      )/8192)
print(p2)
# Out:
# -0.57861328125

# %%
p3=((result3.get_counts(yxxxb)['00000']
     +result3.get_counts(yxxxb)['00011']
     +result3.get_counts(yxxxb)['00101']
     +result3.get_counts(yxxxb)['00110']
     +result3.get_counts(yxxxb)['01001']
     +result3.get_counts(yxxxb)['01010']
     +result3.get_counts(yxxxb)['01100']
     +result3.get_counts(yxxxb)['01111']
     +result3.get_counts(yxxxb)['10001']
     +result3.get_counts(yxxxb)['10010']
     +result3.get_counts(yxxxb)['10100']
     +result3.get_counts(yxxxb)['10111']
     +result3.get_counts(yxxxb)['11000']
     +result3.get_counts(yxxxb)['11011']
     +result3.get_counts(yxxxb)['11101']
     +result3.get_counts(yxxxb)['11110']
       
    -(result3.get_counts(yxxxb)['00001']
     +result3.get_counts(yxxxb)['00010']
     +result3.get_counts(yxxxb)['00100']
     +result3.get_counts(yxxxb)['00111']
     +result3.get_counts(yxxxb)['01000']
     +result3.get_counts(yxxxb)['01011']
     +result3.get_counts(yxxxb)['01101']
     +result3.get_counts(yxxxb)['01110']
     +result3.get_counts(yxxxb)['10000']
     +result3.get_counts(yxxxb)['10011']
     +result3.get_counts(yxxxb)['10101']
     +result3.get_counts(yxxxb)['10110']
     +result3.get_counts(yxxxb)['11001']
     +result3.get_counts(yxxxb)['11010']
     +result3.get_counts(yxxxb)['11100']
     +result3.get_counts(yxxxb)['11111'])
      )/8192)
print(p3)
# Out:
# 0.4189453125

# %%
p4=((result4.get_counts(yyyxa)['00000']
     +result4.get_counts(yyyxa)['00011']
     +result4.get_counts(yyyxa)['00101']
     +result4.get_counts(yyyxa)['00110']
     +result4.get_counts(yyyxa)['01001']
     +result4.get_counts(yyyxa)['01010']
     +result4.get_counts(yyyxa)['01100']
     +result4.get_counts(yyyxa)['01111']
     +result4.get_counts(yyyxa)['10001']
     +result4.get_counts(yyyxa)['10010']
     +result4.get_counts(yyyxa)['10100']
     +result4.get_counts(yyyxa)['10111']
     +result4.get_counts(yyyxa)['11000']
     +result4.get_counts(yyyxa)['11011']
     +result4.get_counts(yyyxa)['11101']
     +result4.get_counts(yyyxa)['11110']
       
    -(result4.get_counts(yyyxa)['00001']
     +result4.get_counts(yyyxa)['00010']
     +result4.get_counts(yyyxa)['00100']
     +result4.get_counts(yyyxa)['00111']
     +result4.get_counts(yyyxa)['01000']
     +result4.get_counts(yyyxa)['01011']
     +result4.get_counts(yyyxa)['01101']
     +result4.get_counts(yyyxa)['01110']
     +result4.get_counts(yyyxa)['10000']
     +result4.get_counts(yyyxa)['10011']
     +result4.get_counts(yyyxa)['10101']
     +result4.get_counts(yyyxa)['10110']
     +result4.get_counts(yyyxa)['11001']
     +result4.get_counts(yyyxa)['11010']
     +result4.get_counts(yyyxa)['11100']
     +result4.get_counts(yyyxa)['11111'])
      )/8192)
print(p4)
# Out:
# 0.623046875

# %%
p5=((result5.get_counts(yyyxb)['00000']
     +result5.get_counts(yyyxb)['00011']
     +result5.get_counts(yyyxb)['00101']
     +result5.get_counts(yyyxb)['00110']
     +result5.get_counts(yyyxb)['01001']
     +result5.get_counts(yyyxb)['01010']
     +result5.get_counts(yyyxb)['01100']
     +result5.get_counts(yyyxb)['01111']
     +result5.get_counts(yyyxb)['10001']
     +result5.get_counts(yyyxb)['10010']
     +result5.get_counts(yyyxb)['10100']
     +result5.get_counts(yyyxb)['10111']
     +result5.get_counts(yyyxb)['11000']
     +result5.get_counts(yyyxb)['11011']
     +result5.get_counts(yyyxb)['11101']
     +result5.get_counts(yyyxb)['11110']
       
    -(result5.get_counts(yyyxb)['00001']
     +result5.get_counts(yyyxb)['00010']
     +result5.get_counts(yyyxb)['00100']
     +result5.get_counts(yyyxb)['00111']
     +result5.get_counts(yyyxb)['01000']
     +result5.get_counts(yyyxb)['01011']
     +result5.get_counts(yyyxb)['01101']
     +result5.get_counts(yyyxb)['01110']
     +result5.get_counts(yyyxb)['10000']
     +result5.get_counts(yyyxb)['10011']
     +result5.get_counts(yyyxb)['10101']
     +result5.get_counts(yyyxb)['10110']
     +result5.get_counts(yyyxb)['11001']
     +result5.get_counts(yyyxb)['11010']
     +result5.get_counts(yyyxb)['11100']
     +result5.get_counts(yyyxb)['11111'])
      )/8192)
print(p5)
# Out:
# -0.306884765625

# %%
print(abs(p1)+abs(p2)+abs(p3)+abs(p4)+abs(p5))
# Out:
# 2.332275390625
