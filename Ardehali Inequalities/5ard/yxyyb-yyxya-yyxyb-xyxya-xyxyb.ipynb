# %%
from qiskit import *
qr1 = QuantumRegister(5)
cr1 = ClassicalRegister(5)
yxyyb = QuantumCircuit(qr1, cr1)
# %matplotlib inline
yxyyb.h(qr1[0])
yxyyb.h(qr1[1])
yxyyb.h(qr1[3])
yxyyb.h(qr1[4])
yxyyb.cx(qr1[1],qr1[2])
yxyyb.h(qr1[1])
yxyyb.cx(qr1[3],qr1[2])
yxyyb.h(qr1[3])
yxyyb.cx(qr1[4],qr1[2])
yxyyb.cx(qr1[0],qr1[2])
yxyyb.h(qr1[0])
yxyyb.h(qr1[2])
yxyyb.h(qr1[4])

yxyyb.barrier(qr1)

yxyyb.sdg(qr1[0])
yxyyb.h(qr1[0])
yxyyb.h(qr1[1])
yxyyb.sdg(qr1[2])
yxyyb.h(qr1[2])
yxyyb.sdg(qr1[3])
yxyyb.h(qr1[3])
yxyyb.t(qr1[4])
yxyyb.h(qr1[4])
yxyyb.measure(qr1, cr1)
yxyyb.draw(output='mpl')

# %%
qr2 = QuantumRegister(5)
cr2 = ClassicalRegister(5)
yyxya = QuantumCircuit(qr2, cr2)
# %matplotlib inline
yyxya.h(qr2[0])
yyxya.h(qr2[1])
yyxya.h(qr2[3])
yyxya.h(qr2[4])
yyxya.cx(qr2[1],qr2[2])
yyxya.h(qr2[1])
yyxya.cx(qr2[3],qr2[2])
yyxya.h(qr2[3])
yyxya.cx(qr2[4],qr2[2])
yyxya.cx(qr2[0],qr2[2])
yyxya.h(qr2[0])
yyxya.h(qr2[2])
yyxya.h(qr2[4])

yyxya.barrier(qr2)

yyxya.sdg(qr2[0])
yyxya.h(qr2[0])
yyxya.sdg(qr2[1])
yyxya.h(qr2[1])
yyxya.h(qr2[2])
yyxya.sdg(qr2[3])
yyxya.h(qr2[3])
yyxya.tdg(qr2[4])
yyxya.h(qr2[4])
yyxya.measure(qr2, cr2)
yyxya.draw(output='mpl')

# %%
qr3 = QuantumRegister(5)
cr3 = ClassicalRegister(5)
yyxyb = QuantumCircuit(qr3, cr3)
# %matplotlib inline
yyxyb.h(qr3[0])
yyxyb.h(qr3[1])
yyxyb.h(qr3[3])
yyxyb.h(qr3[4])
yyxyb.cx(qr3[1],qr3[2])
yyxyb.h(qr3[1])
yyxyb.cx(qr3[3],qr3[2])
yyxyb.h(qr3[3])
yyxyb.cx(qr3[4],qr3[2])
yyxyb.cx(qr3[0],qr3[2])
yyxyb.h(qr3[0])
yyxyb.h(qr3[2])
yyxyb.h(qr3[4])

yyxyb.barrier(qr3)

yyxyb.sdg(qr3[0])
yyxyb.h(qr3[0])
yyxyb.sdg(qr3[1])
yyxyb.h(qr3[1])
yyxyb.h(qr3[2])
yyxyb.sdg(qr3[3])
yyxyb.h(qr3[3])
yyxyb.t(qr3[4])
yyxyb.h(qr3[4])
yyxyb.measure(qr3, cr3)
yyxyb.draw(output='mpl')

# %%
qr4 = QuantumRegister(5)
cr4 = ClassicalRegister(5)
xyxya = QuantumCircuit(qr4, cr4)
# %matplotlib inline
xyxya.h(qr4[0])
xyxya.h(qr4[1])
xyxya.h(qr4[3])
xyxya.h(qr4[4])
xyxya.cx(qr4[1],qr4[2])
xyxya.h(qr4[1])
xyxya.cx(qr4[3],qr4[2])
xyxya.h(qr4[3])
xyxya.cx(qr4[4],qr4[2])
xyxya.cx(qr4[0],qr4[2])
xyxya.h(qr4[0])
xyxya.h(qr4[2])
xyxya.h(qr4[4])

xyxya.barrier(qr4)

xyxya.h(qr4[0])
xyxya.sdg(qr4[1])
xyxya.h(qr4[1])
xyxya.h(qr4[2])
xyxya.sdg(qr4[3])
xyxya.h(qr4[3])
xyxya.tdg(qr4[4])
xyxya.h(qr4[4])
xyxya.measure(qr4, cr4)
xyxya.draw(output='mpl')

# %%
qr5 = QuantumRegister(5)
cr5 = ClassicalRegister(5)
xyxyb = QuantumCircuit(qr5, cr5)
# %matplotlib inline
xyxyb.h(qr5[0])
xyxyb.h(qr5[1])
xyxyb.h(qr5[3])
xyxyb.h(qr5[4])
xyxyb.cx(qr5[1],qr5[2])
xyxyb.h(qr5[1])
xyxyb.cx(qr5[3],qr5[2])
xyxyb.h(qr5[3])
xyxyb.cx(qr5[4],qr5[2])
xyxyb.cx(qr5[0],qr5[2])
xyxyb.h(qr5[0])
xyxyb.h(qr5[2])
xyxyb.h(qr5[4])

xyxyb.barrier(qr5)

xyxyb.h(qr5[0])
xyxyb.sdg(qr5[1])
xyxyb.h(qr5[1])
xyxyb.h(qr5[2])
xyxyb.sdg(qr5[3])
xyxyb.h(qr5[3])
xyxyb.t(qr5[4])
xyxyb.h(qr5[4])
xyxyb.measure(qr5, cr5)
xyxyb.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_athens')
job1 = execute(yxyyb, backend=qcomp,shots = 8192)
job2 = execute(yyxya, backend=qcomp,shots = 8192)
job3 = execute(yyxyb, backend=qcomp,shots = 8192)
job4 = execute(xyxya, backend=qcomp,shots = 8192)
job5 = execute(xyxyb, backend=qcomp,shots = 8192)
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job1)
job_monitor(job2)
job_monitor(job3)
job_monitor(job4)
job_monitor(job5)
# Out:
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run

# %%
result1 = job1.result()
result2 = job2.result()
result3 = job3.result()
result4 = job4.result()
result5 = job5.result()
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result1.get_counts(yxyyb))

# %%
plot_histogram(result2.get_counts(yyxya))

# %%
plot_histogram(result3.get_counts(yyxyb))

# %%
plot_histogram(result4.get_counts(xyxya))

# %%
plot_histogram(result5.get_counts(xyxyb))

# %%
p1= ((result1.get_counts(yxyyb)['00000']
     +result1.get_counts(yxyyb)['00011']
     +result1.get_counts(yxyyb)['00101']
     +result1.get_counts(yxyyb)['00110']
     +result1.get_counts(yxyyb)['01001']
     +result1.get_counts(yxyyb)['01010']
     +result1.get_counts(yxyyb)['01100']
     +result1.get_counts(yxyyb)['01111']
     +result1.get_counts(yxyyb)['10001']
     +result1.get_counts(yxyyb)['10010']
     +result1.get_counts(yxyyb)['10100']
     +result1.get_counts(yxyyb)['10111']
     +result1.get_counts(yxyyb)['11000']
     +result1.get_counts(yxyyb)['11011']
     +result1.get_counts(yxyyb)['11101']
     +result1.get_counts(yxyyb)['11110']
       
    -(result1.get_counts(yxyyb)['00001']
     +result1.get_counts(yxyyb)['00010']
     +result1.get_counts(yxyyb)['00100']
     +result1.get_counts(yxyyb)['00111']
     +result1.get_counts(yxyyb)['01000']
     +result1.get_counts(yxyyb)['01011']
     +result1.get_counts(yxyyb)['01101']
     +result1.get_counts(yxyyb)['01110']
     +result1.get_counts(yxyyb)['10000']
     +result1.get_counts(yxyyb)['10011']
     +result1.get_counts(yxyyb)['10101']
     +result1.get_counts(yxyyb)['10110']
     +result1.get_counts(yxyyb)['11001']
     +result1.get_counts(yxyyb)['11010']
     +result1.get_counts(yxyyb)['11100']
     +result1.get_counts(yxyyb)['11111'])
      )/8192)
print(p1)
# Out:
# -0.396240234375

# %%
p2=((result2.get_counts(yyxya)['00000']
     +result2.get_counts(yyxya)['00011']
     +result2.get_counts(yyxya)['00101']
     +result2.get_counts(yyxya)['00110']
     +result2.get_counts(yyxya)['01001']
     +result2.get_counts(yyxya)['01010']
     +result2.get_counts(yyxya)['01100']
     +result2.get_counts(yyxya)['01111']
     +result2.get_counts(yyxya)['10001']
     +result2.get_counts(yyxya)['10010']
     +result2.get_counts(yyxya)['10100']
     +result2.get_counts(yyxya)['10111']
     +result2.get_counts(yyxya)['11000']
     +result2.get_counts(yyxya)['11011']
     +result2.get_counts(yyxya)['11101']
     +result2.get_counts(yyxya)['11110']
       
    -(result2.get_counts(yyxya)['00001']
     +result2.get_counts(yyxya)['00010']
     +result2.get_counts(yyxya)['00100']
     +result2.get_counts(yyxya)['00111']
     +result2.get_counts(yyxya)['01000']
     +result2.get_counts(yyxya)['01011']
     +result2.get_counts(yyxya)['01101']
     +result2.get_counts(yyxya)['01110']
     +result2.get_counts(yyxya)['10000']
     +result2.get_counts(yyxya)['10011']
     +result2.get_counts(yyxya)['10101']
     +result2.get_counts(yyxya)['10110']
     +result2.get_counts(yyxya)['11001']
     +result2.get_counts(yyxya)['11010']
     +result2.get_counts(yyxya)['11100']
     +result2.get_counts(yyxya)['11111'])
      )/8192)
print(p2)
# Out:
# 0.625244140625

# %%
p3=((result3.get_counts(yyxyb)['00000']
     +result3.get_counts(yyxyb)['00011']
     +result3.get_counts(yyxyb)['00101']
     +result3.get_counts(yyxyb)['00110']
     +result3.get_counts(yyxyb)['01001']
     +result3.get_counts(yyxyb)['01010']
     +result3.get_counts(yyxyb)['01100']
     +result3.get_counts(yyxyb)['01111']
     +result3.get_counts(yyxyb)['10001']
     +result3.get_counts(yyxyb)['10010']
     +result3.get_counts(yyxyb)['10100']
     +result3.get_counts(yyxyb)['10111']
     +result3.get_counts(yyxyb)['11000']
     +result3.get_counts(yyxyb)['11011']
     +result3.get_counts(yyxyb)['11101']
     +result3.get_counts(yyxyb)['11110']
       
    -(result3.get_counts(yyxyb)['00001']
     +result3.get_counts(yyxyb)['00010']
     +result3.get_counts(yyxyb)['00100']
     +result3.get_counts(yyxyb)['00111']
     +result3.get_counts(yyxyb)['01000']
     +result3.get_counts(yyxyb)['01011']
     +result3.get_counts(yyxyb)['01101']
     +result3.get_counts(yyxyb)['01110']
     +result3.get_counts(yyxyb)['10000']
     +result3.get_counts(yyxyb)['10011']
     +result3.get_counts(yyxyb)['10101']
     +result3.get_counts(yyxyb)['10110']
     +result3.get_counts(yyxyb)['11001']
     +result3.get_counts(yyxyb)['11010']
     +result3.get_counts(yyxyb)['11100']
     +result3.get_counts(yyxyb)['11111'])
      )/8192)
print(p3)
# Out:
# -0.322021484375

# %%
p4=((result4.get_counts(xyxya)['00000']
     +result4.get_counts(xyxya)['00011']
     +result4.get_counts(xyxya)['00101']
     +result4.get_counts(xyxya)['00110']
     +result4.get_counts(xyxya)['01001']
     +result4.get_counts(xyxya)['01010']
     +result4.get_counts(xyxya)['01100']
     +result4.get_counts(xyxya)['01111']
     +result4.get_counts(xyxya)['10001']
     +result4.get_counts(xyxya)['10010']
     +result4.get_counts(xyxya)['10100']
     +result4.get_counts(xyxya)['10111']
     +result4.get_counts(xyxya)['11000']
     +result4.get_counts(xyxya)['11011']
     +result4.get_counts(xyxya)['11101']
     +result4.get_counts(xyxya)['11110']
       
    -(result4.get_counts(xyxya)['00001']
     +result4.get_counts(xyxya)['00010']
     +result4.get_counts(xyxya)['00100']
     +result4.get_counts(xyxya)['00111']
     +result4.get_counts(xyxya)['01000']
     +result4.get_counts(xyxya)['01011']
     +result4.get_counts(xyxya)['01101']
     +result4.get_counts(xyxya)['01110']
     +result4.get_counts(xyxya)['10000']
     +result4.get_counts(xyxya)['10011']
     +result4.get_counts(xyxya)['10101']
     +result4.get_counts(xyxya)['10110']
     +result4.get_counts(xyxya)['11001']
     +result4.get_counts(xyxya)['11010']
     +result4.get_counts(xyxya)['11100']
     +result4.get_counts(xyxya)['11111'])
      )/8192)
print(p4)
# Out:
# -0.332763671875

# %%
p5=((result5.get_counts(xyxyb)['00000']
     +result5.get_counts(xyxyb)['00011']
     +result5.get_counts(xyxyb)['00101']
     +result5.get_counts(xyxyb)['00110']
     +result5.get_counts(xyxyb)['01001']
     +result5.get_counts(xyxyb)['01010']
     +result5.get_counts(xyxyb)['01100']
     +result5.get_counts(xyxyb)['01111']
     +result5.get_counts(xyxyb)['10001']
     +result5.get_counts(xyxyb)['10010']
     +result5.get_counts(xyxyb)['10100']
     +result5.get_counts(xyxyb)['10111']
     +result5.get_counts(xyxyb)['11000']
     +result5.get_counts(xyxyb)['11011']
     +result5.get_counts(xyxyb)['11101']
     +result5.get_counts(xyxyb)['11110']
       
    -(result5.get_counts(xyxyb)['00001']
     +result5.get_counts(xyxyb)['00010']
     +result5.get_counts(xyxyb)['00100']
     +result5.get_counts(xyxyb)['00111']
     +result5.get_counts(xyxyb)['01000']
     +result5.get_counts(xyxyb)['01011']
     +result5.get_counts(xyxyb)['01101']
     +result5.get_counts(xyxyb)['01110']
     +result5.get_counts(xyxyb)['10000']
     +result5.get_counts(xyxyb)['10011']
     +result5.get_counts(xyxyb)['10101']
     +result5.get_counts(xyxyb)['10110']
     +result5.get_counts(xyxyb)['11001']
     +result5.get_counts(xyxyb)['11010']
     +result5.get_counts(xyxyb)['11100']
     +result5.get_counts(xyxyb)['11111'])
      )/8192)
print(p5)
# Out:
# -0.62060546875

# %%
print(abs(p1)+abs(p2)+abs(p3)+abs(p4)+abs(p5))
# Out:
# 2.296875
