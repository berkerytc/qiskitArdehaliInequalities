# %%
from qiskit import *
qr1 = QuantumRegister(5)
cr1 = ClassicalRegister(5)
xxxxa = QuantumCircuit(qr1, cr1)
# %matplotlib inline
xxxxa.h(qr1[0])
xxxxa.h(qr1[1])
xxxxa.h(qr1[3])
xxxxa.h(qr1[4])
xxxxa.cx(qr1[1],qr1[2])
xxxxa.h(qr1[1])
xxxxa.cx(qr1[3],qr1[2])
xxxxa.h(qr1[3])
xxxxa.cx(qr1[4],qr1[2])
xxxxa.cx(qr1[0],qr1[2])
xxxxa.h(qr1[0])
xxxxa.h(qr1[2])
xxxxa.h(qr1[4])

xxxxa.barrier(qr1)

xxxxa.h(qr1[0])
xxxxa.h(qr1[1])
xxxxa.h(qr1[2])
xxxxa.h(qr1[3])
xxxxa.tdg(qr1[4])
xxxxa.h(qr1[4])
xxxxa.measure(qr1, cr1)
xxxxa.draw(output='mpl')

# %%
qr2 = QuantumRegister(5)
cr2 = ClassicalRegister(5)
xxxxb = QuantumCircuit(qr2, cr2)
# %matplotlib inline
xxxxb.h(qr2[0])
xxxxb.h(qr2[1])
xxxxb.h(qr2[3])
xxxxb.h(qr2[4])
xxxxb.cx(qr2[1],qr2[2])
xxxxb.h(qr2[1])
xxxxb.cx(qr2[3],qr2[2])
xxxxb.h(qr2[3])
xxxxb.cx(qr2[4],qr2[2])
xxxxb.cx(qr2[0],qr2[2])
xxxxb.h(qr2[0])
xxxxb.h(qr2[2])
xxxxb.h(qr2[4])

xxxxb.barrier(qr2)

xxxxb.h(qr2[0])
xxxxb.h(qr2[1])
xxxxb.h(qr2[2])
xxxxb.h(qr2[3])
xxxxb.t(qr2[4])
xxxxb.h(qr2[4])
xxxxb.measure(qr2, cr2)
xxxxb.draw(output='mpl')

# %%
qr3 = QuantumRegister(5)
cr3 = ClassicalRegister(5)
xyyxa = QuantumCircuit(qr3, cr3)
# %matplotlib inline
xyyxa.h(qr3[0])
xyyxa.h(qr3[1])
xyyxa.h(qr3[3])
xyyxa.h(qr3[4])
xyyxa.cx(qr3[1],qr3[2])
xyyxa.h(qr3[1])
xyyxa.cx(qr3[3],qr3[2])
xyyxa.h(qr3[3])
xyyxa.cx(qr3[4],qr3[2])
xyyxa.cx(qr3[0],qr3[2])
xyyxa.h(qr3[0])
xyyxa.h(qr3[2])
xyyxa.h(qr3[4])

xyyxa.barrier(qr3)

xyyxa.h(qr3[0])
xyyxa.sdg(qr3[1])
xyyxa.h(qr3[1])
xyyxa.sdg(qr3[2])
xyyxa.h(qr3[2])
xyyxa.h(qr3[3])
xyyxa.tdg(qr3[4])
xyyxa.h(qr3[4])
xyyxa.measure(qr3, cr3)
xyyxa.draw(output='mpl')

# %%
qr4 = QuantumRegister(5)
cr4 = ClassicalRegister(5)
xyyxb = QuantumCircuit(qr4, cr4)
# %matplotlib inline
xyyxb.h(qr4[0])
xyyxb.h(qr4[1])
xyyxb.h(qr4[3])
xyyxb.h(qr4[4])
xyyxb.cx(qr4[1],qr4[2])
xyyxb.h(qr4[1])
xyyxb.cx(qr4[3],qr4[2])
xyyxb.h(qr4[3])
xyyxb.cx(qr4[4],qr4[2])
xyyxb.cx(qr4[0],qr4[2])
xyyxb.h(qr4[0])
xyyxb.h(qr4[2])
xyyxb.h(qr4[4])

xyyxb.barrier(qr4)

xyyxb.h(qr4[0])
xyyxb.sdg(qr4[1])
xyyxb.h(qr4[1])
xyyxb.sdg(qr4[2])
xyyxb.h(qr4[2])
xyyxb.h(qr4[3])
xyyxb.t(qr4[4])
xyyxb.h(qr4[4])
xyyxb.measure(qr4, cr4)
xyyxb.draw(output='mpl')

# %%
qr5 = QuantumRegister(5)
cr5 = ClassicalRegister(5)
yxyxa = QuantumCircuit(qr5, cr5)
# %matplotlib inline
yxyxa.h(qr5[0])
yxyxa.h(qr5[1])
yxyxa.h(qr5[3])
yxyxa.h(qr5[4])
yxyxa.cx(qr5[1],qr5[2])
yxyxa.h(qr5[1])
yxyxa.cx(qr5[3],qr5[2])
yxyxa.h(qr5[3])
yxyxa.cx(qr5[4],qr5[2])
yxyxa.cx(qr5[0],qr5[2])
yxyxa.h(qr5[0])
yxyxa.h(qr5[2])
yxyxa.h(qr5[4])

yxyxa.barrier(qr5)

yxyxa.sdg(qr5[0])
yxyxa.h(qr5[0])
yxyxa.h(qr5[1])
yxyxa.sdg(qr5[2])
yxyxa.h(qr5[2])
yxyxa.h(qr5[3])
yxyxa.tdg(qr5[4])
yxyxa.h(qr5[4])
yxyxa.measure(qr5, cr5)
yxyxa.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_athens')
job1 = execute(xxxxa, backend=qcomp,shots = 8192)
job2 = execute(xxxxb, backend=qcomp,shots = 8192)
job3 = execute(xyyxa, backend=qcomp,shots = 8192)
job4 = execute(xyyxb, backend=qcomp,shots = 8192)
job5 = execute(yxyxa, backend=qcomp,shots = 8192)
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job1)
job_monitor(job2)
job_monitor(job3)
job_monitor(job4)
job_monitor(job5)
# Out:
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run

# %%
result1 = job1.result()
result2 = job2.result()
result3 = job3.result()
result4 = job4.result()
result5 = job5.result()
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result1.get_counts(xxxxa))

# %%
plot_histogram(result2.get_counts(xxxxb))

# %%
plot_histogram(result3.get_counts(xyyxa))

# %%
plot_histogram(result4.get_counts(xyyxb))

# %%
plot_histogram(result5.get_counts(yxyxa))

# %%
p1= ((result1.get_counts(xxxxa)['00000']
     +result1.get_counts(xxxxa)['00011']
     +result1.get_counts(xxxxa)['00101']
     +result1.get_counts(xxxxa)['00110']
     +result1.get_counts(xxxxa)['01001']
     +result1.get_counts(xxxxa)['01010']
     +result1.get_counts(xxxxa)['01100']
     +result1.get_counts(xxxxa)['01111']
     +result1.get_counts(xxxxa)['10001']
     +result1.get_counts(xxxxa)['10010']
     +result1.get_counts(xxxxa)['10100']
     +result1.get_counts(xxxxa)['10111']
     +result1.get_counts(xxxxa)['11000']
     +result1.get_counts(xxxxa)['11011']
     +result1.get_counts(xxxxa)['11101']
     +result1.get_counts(xxxxa)['11110']
       
    -(result1.get_counts(xxxxa)['00001']
     +result1.get_counts(xxxxa)['00010']
     +result1.get_counts(xxxxa)['00100']
     +result1.get_counts(xxxxa)['00111']
     +result1.get_counts(xxxxa)['01000']
     +result1.get_counts(xxxxa)['01011']
     +result1.get_counts(xxxxa)['01101']
     +result1.get_counts(xxxxa)['01110']
     +result1.get_counts(xxxxa)['10000']
     +result1.get_counts(xxxxa)['10011']
     +result1.get_counts(xxxxa)['10101']
     +result1.get_counts(xxxxa)['10110']
     +result1.get_counts(xxxxa)['11001']
     +result1.get_counts(xxxxa)['11010']
     +result1.get_counts(xxxxa)['11100']
     +result1.get_counts(xxxxa)['11111'])
      )/8192)
print(p1)
# Out:
# 0.42626953125

# %%
p2= ((result2.get_counts(xxxxb)['00000']
     +result2.get_counts(xxxxb)['00011']
     +result2.get_counts(xxxxb)['00101']
     +result2.get_counts(xxxxb)['00110']
     +result2.get_counts(xxxxb)['01001']
     +result2.get_counts(xxxxb)['01010']
     +result2.get_counts(xxxxb)['01100']
     +result2.get_counts(xxxxb)['01111']
     +result2.get_counts(xxxxb)['10001']
     +result2.get_counts(xxxxb)['10010']
     +result2.get_counts(xxxxb)['10100']
     +result2.get_counts(xxxxb)['10111']
     +result2.get_counts(xxxxb)['11000']
     +result2.get_counts(xxxxb)['11011']
     +result2.get_counts(xxxxb)['11101']
     +result2.get_counts(xxxxb)['11110']
       
    -(result2.get_counts(xxxxb)['00001']
     +result2.get_counts(xxxxb)['00010']
     +result2.get_counts(xxxxb)['00100']
     +result2.get_counts(xxxxb)['00111']
     +result2.get_counts(xxxxb)['01000']
     +result2.get_counts(xxxxb)['01011']
     +result2.get_counts(xxxxb)['01101']
     +result2.get_counts(xxxxb)['01110']
     +result2.get_counts(xxxxb)['10000']
     +result2.get_counts(xxxxb)['10011']
     +result2.get_counts(xxxxb)['10101']
     +result2.get_counts(xxxxb)['10110']
     +result2.get_counts(xxxxb)['11001']
     +result2.get_counts(xxxxb)['11010']
     +result2.get_counts(xxxxb)['11100']
     +result2.get_counts(xxxxb)['11111'])
      )/8192)
print(p2)
# Out:
# 0.648681640625

# %%
p3=((result3.get_counts(xyyxa)['00000']
     +result3.get_counts(xyyxa)['00011']
     +result3.get_counts(xyyxa)['00101']
     +result3.get_counts(xyyxa)['00110']
     +result3.get_counts(xyyxa)['01001']
     +result3.get_counts(xyyxa)['01010']
     +result3.get_counts(xyyxa)['01100']
     +result3.get_counts(xyyxa)['01111']
     +result3.get_counts(xyyxa)['10001']
     +result3.get_counts(xyyxa)['10010']
     +result3.get_counts(xyyxa)['10100']
     +result3.get_counts(xyyxa)['10111']
     +result3.get_counts(xyyxa)['11000']
     +result3.get_counts(xyyxa)['11011']
     +result3.get_counts(xyyxa)['11101']
     +result3.get_counts(xyyxa)['11110']
       
    -(result3.get_counts(xyyxa)['00001']
     +result3.get_counts(xyyxa)['00010']
     +result3.get_counts(xyyxa)['00100']
     +result3.get_counts(xyyxa)['00111']
     +result3.get_counts(xyyxa)['01000']
     +result3.get_counts(xyyxa)['01011']
     +result3.get_counts(xyyxa)['01101']
     +result3.get_counts(xyyxa)['01110']
     +result3.get_counts(xyyxa)['10000']
     +result3.get_counts(xyyxa)['10011']
     +result3.get_counts(xyyxa)['10101']
     +result3.get_counts(xyyxa)['10110']
     +result3.get_counts(xyyxa)['11001']
     +result3.get_counts(xyyxa)['11010']
     +result3.get_counts(xyyxa)['11100']
     +result3.get_counts(xyyxa)['11111'])
      )/8192)
print(p3)
# Out:
# -0.42041015625

# %%
p4 = ((result4.get_counts(xyyxb)['00000']
     +result4.get_counts(xyyxb)['00011']
     +result4.get_counts(xyyxb)['00101']
     +result4.get_counts(xyyxb)['00110']
     +result4.get_counts(xyyxb)['01001']
     +result4.get_counts(xyyxb)['01010']
     +result4.get_counts(xyyxb)['01100']
     +result4.get_counts(xyyxb)['01111']
     +result4.get_counts(xyyxb)['10001']
     +result4.get_counts(xyyxb)['10010']
     +result4.get_counts(xyyxb)['10100']
     +result4.get_counts(xyyxb)['10111']
     +result4.get_counts(xyyxb)['11000']
     +result4.get_counts(xyyxb)['11011']
     +result4.get_counts(xyyxb)['11101']
     +result4.get_counts(xyyxb)['11110']
       
    -(result4.get_counts(xyyxb)['00001']
     +result4.get_counts(xyyxb)['00010']
     +result4.get_counts(xyyxb)['00100']
     +result4.get_counts(xyyxb)['00111']
     +result4.get_counts(xyyxb)['01000']
     +result4.get_counts(xyyxb)['01011']
     +result4.get_counts(xyyxb)['01101']
     +result4.get_counts(xyyxb)['01110']
     +result4.get_counts(xyyxb)['10000']
     +result4.get_counts(xyyxb)['10011']
     +result4.get_counts(xyyxb)['10101']
     +result4.get_counts(xyyxb)['10110']
     +result4.get_counts(xyyxb)['11001']
     +result4.get_counts(xyyxb)['11010']
     +result4.get_counts(xyyxb)['11100']
     +result4.get_counts(xyyxb)['11111'])
      )/8192)
print(p4)
# Out:
# -0.625244140625

# %%
p5 = ((result5.get_counts(yxyxa)['00000']
     +result5.get_counts(yxyxa)['00011']
     +result5.get_counts(yxyxa)['00101']
     +result5.get_counts(yxyxa)['00110']
     +result5.get_counts(yxyxa)['01001']
     +result5.get_counts(yxyxa)['01010']
     +result5.get_counts(yxyxa)['01100']
     +result5.get_counts(yxyxa)['01111']
     +result5.get_counts(yxyxa)['10001']
     +result5.get_counts(yxyxa)['10010']
     +result5.get_counts(yxyxa)['10100']
     +result5.get_counts(yxyxa)['10111']
     +result5.get_counts(yxyxa)['11000']
     +result5.get_counts(yxyxa)['11011']
     +result5.get_counts(yxyxa)['11101']
     +result5.get_counts(yxyxa)['11110']
       
    -(result5.get_counts(yxyxa)['00001']
     +result5.get_counts(yxyxa)['00010']
     +result5.get_counts(yxyxa)['00100']
     +result5.get_counts(yxyxa)['00111']
     +result5.get_counts(yxyxa)['01000']
     +result5.get_counts(yxyxa)['01011']
     +result5.get_counts(yxyxa)['01101']
     +result5.get_counts(yxyxa)['01110']
     +result5.get_counts(yxyxa)['10000']
     +result5.get_counts(yxyxa)['10011']
     +result5.get_counts(yxyxa)['10101']
     +result5.get_counts(yxyxa)['10110']
     +result5.get_counts(yxyxa)['11001']
     +result5.get_counts(yxyxa)['11010']
     +result5.get_counts(yxyxa)['11100']
     +result5.get_counts(yxyxa)['11111'])
      )/8192)
print(p5)
# Out:
# -0.32421875

# %%
print(abs(p1)+abs(p2)+abs(p3)+abs(p4)+abs(p5))
# Out:
# 2.44482421875
