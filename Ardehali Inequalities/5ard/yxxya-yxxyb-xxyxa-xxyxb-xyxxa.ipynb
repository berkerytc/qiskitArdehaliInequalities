# %%
from qiskit import *
qr1 = QuantumRegister(5)
cr1 = ClassicalRegister(5)
yxxya = QuantumCircuit(qr1, cr1)
# %matplotlib inline
yxxya.h(qr1[0])
yxxya.h(qr1[1])
yxxya.h(qr1[3])
yxxya.h(qr1[4])
yxxya.cx(qr1[1],qr1[2])
yxxya.h(qr1[1])
yxxya.cx(qr1[3],qr1[2])
yxxya.h(qr1[3])
yxxya.cx(qr1[4],qr1[2])
yxxya.cx(qr1[0],qr1[2])
yxxya.h(qr1[0])
yxxya.h(qr1[2])
yxxya.h(qr1[4])

yxxya.barrier(qr1)

yxxya.sdg(qr1[0])
yxxya.h(qr1[0])
yxxya.h(qr1[1])
yxxya.h(qr1[2])
yxxya.sdg(qr1[3])
yxxya.h(qr1[3])
yxxya.tdg(qr1[4])
yxxya.h(qr1[4])
yxxya.measure(qr1, cr1)
yxxya.draw(output='mpl')

# %%
qr2 = QuantumRegister(5)
cr2 = ClassicalRegister(5)
yxxyb = QuantumCircuit(qr2, cr2)
# %matplotlib inline
yxxyb.h(qr2[0])
yxxyb.h(qr2[1])
yxxyb.h(qr2[3])
yxxyb.h(qr2[4])
yxxyb.cx(qr2[1],qr2[2])
yxxyb.h(qr2[1])
yxxyb.cx(qr2[3],qr2[2])
yxxyb.h(qr2[3])
yxxyb.cx(qr2[4],qr2[2])
yxxyb.cx(qr2[0],qr2[2])
yxxyb.h(qr2[0])
yxxyb.h(qr2[2])
yxxyb.h(qr2[4])

yxxyb.barrier(qr2)

yxxyb.sdg(qr2[0])
yxxyb.h(qr2[0])
yxxyb.h(qr2[1])
yxxyb.h(qr2[2])
yxxyb.sdg(qr2[3])
yxxyb.h(qr2[3])
yxxyb.t(qr2[4])
yxxyb.h(qr2[4])
yxxyb.measure(qr2, cr2)
yxxyb.draw(output='mpl')

# %%
qr3 = QuantumRegister(5)
cr3 = ClassicalRegister(5)
xxyxa = QuantumCircuit(qr3, cr3)
# %matplotlib inline
xxyxa.h(qr3[0])
xxyxa.h(qr3[1])
xxyxa.h(qr3[3])
xxyxa.h(qr3[4])
xxyxa.cx(qr3[1],qr3[2])
xxyxa.h(qr3[1])
xxyxa.cx(qr3[3],qr3[2])
xxyxa.h(qr3[3])
xxyxa.cx(qr3[4],qr3[2])
xxyxa.cx(qr3[0],qr3[2])
xxyxa.h(qr3[0])
xxyxa.h(qr3[2])
xxyxa.h(qr3[4])

xxyxa.barrier(qr3)

xxyxa.h(qr3[0])
xxyxa.h(qr3[1])
xxyxa.sdg(qr3[2])
xxyxa.h(qr3[2])
xxyxa.h(qr3[3])
xxyxa.tdg(qr3[4])
xxyxa.h(qr3[4])
xxyxa.measure(qr3, cr3)
xxyxa.draw(output='mpl')

# %%
qr4 = QuantumRegister(5)
cr4 = ClassicalRegister(5)
xxyxb = QuantumCircuit(qr4, cr4)
# %matplotlib inline
xxyxb.h(qr4[0])
xxyxb.h(qr4[1])
xxyxb.h(qr4[3])
xxyxb.h(qr4[4])
xxyxb.cx(qr4[1],qr4[2])
xxyxb.h(qr4[1])
xxyxb.cx(qr4[3],qr4[2])
xxyxb.h(qr4[3])
xxyxb.cx(qr4[4],qr4[2])
xxyxb.cx(qr4[0],qr4[2])
xxyxb.h(qr4[0])
xxyxb.h(qr4[2])
xxyxb.h(qr4[4])

xxyxb.barrier(qr4)

xxyxb.h(qr4[0])
xxyxb.h(qr4[1])
xxyxb.sdg(qr4[2])
xxyxb.h(qr4[2])
xxyxb.h(qr4[3])
xxyxb.t(qr4[4])
xxyxb.h(qr4[4])
xxyxb.measure(qr4, cr4)
xxyxb.draw(output='mpl')

# %%
qr5 = QuantumRegister(5)
cr5 = ClassicalRegister(5)
xyxxa = QuantumCircuit(qr5, cr5)
# %matplotlib inline
xyxxa.h(qr5[0])
xyxxa.h(qr5[1])
xyxxa.h(qr5[3])
xyxxa.h(qr5[4])
xyxxa.cx(qr5[1],qr5[2])
xyxxa.h(qr5[1])
xyxxa.cx(qr5[3],qr5[2])
xyxxa.h(qr5[3])
xyxxa.cx(qr5[4],qr5[2])
xyxxa.cx(qr5[0],qr5[2])
xyxxa.h(qr5[0])
xyxxa.h(qr5[2])
xyxxa.h(qr5[4])

xyxxa.barrier(qr5)

xyxxa.h(qr5[0])
xyxxa.sdg(qr5[1])
xyxxa.h(qr5[1])
xyxxa.h(qr5[2])
xyxxa.h(qr5[3])
xyxxa.tdg(qr5[4])
xyxxa.h(qr5[4])
xyxxa.measure(qr5, cr5)
xyxxa.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_athens')
job1 = execute(yxxya, backend=qcomp,shots = 8192)
job2 = execute(yxxyb, backend=qcomp,shots = 8192)
job3 = execute(xxyxa, backend=qcomp,shots = 8192)
job4 = execute(xxyxb, backend=qcomp,shots = 8192)
job5 = execute(xyxxa, backend=qcomp,shots = 8192)
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job1)
job_monitor(job2)
job_monitor(job3)
job_monitor(job4)
job_monitor(job5)
# Out:
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run
# Job Status: job has successfully run

# %%
result1 = job1.result()
result2 = job2.result()
result3 = job3.result()
result4 = job4.result()
result5 = job5.result()
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result1.get_counts(yxxya))

# %%
plot_histogram(result2.get_counts(yxxyb))

# %%
plot_histogram(result3.get_counts(xxyxa))

# %%
plot_histogram(result4.get_counts(xxyxb))

# %%
plot_histogram(result5.get_counts(xyxxa))

# %%
p1= ((result1.get_counts(yxxya)['00000']
     +result1.get_counts(yxxya)['00011']
     +result1.get_counts(yxxya)['00101']
     +result1.get_counts(yxxya)['00110']
     +result1.get_counts(yxxya)['01001']
     +result1.get_counts(yxxya)['01010']
     +result1.get_counts(yxxya)['01100']
     +result1.get_counts(yxxya)['01111']
     +result1.get_counts(yxxya)['10001']
     +result1.get_counts(yxxya)['10010']
     +result1.get_counts(yxxya)['10100']
     +result1.get_counts(yxxya)['10111']
     +result1.get_counts(yxxya)['11000']
     +result1.get_counts(yxxya)['11011']
     +result1.get_counts(yxxya)['11101']
     +result1.get_counts(yxxya)['11110']
       
    -(result1.get_counts(yxxya)['00001']
     +result1.get_counts(yxxya)['00010']
     +result1.get_counts(yxxya)['00100']
     +result1.get_counts(yxxya)['00111']
     +result1.get_counts(yxxya)['01000']
     +result1.get_counts(yxxya)['01011']
     +result1.get_counts(yxxya)['01101']
     +result1.get_counts(yxxya)['01110']
     +result1.get_counts(yxxya)['10000']
     +result1.get_counts(yxxya)['10011']
     +result1.get_counts(yxxya)['10101']
     +result1.get_counts(yxxya)['10110']
     +result1.get_counts(yxxya)['11001']
     +result1.get_counts(yxxya)['11010']
     +result1.get_counts(yxxya)['11100']
     +result1.get_counts(yxxya)['11111'])
      )/8192)
print(p1)
# Out:
# -0.31982421875

# %%
p2=((result2.get_counts(yxxyb)['00000']
     +result2.get_counts(yxxyb)['00011']
     +result2.get_counts(yxxyb)['00101']
     +result2.get_counts(yxxyb)['00110']
     +result2.get_counts(yxxyb)['01001']
     +result2.get_counts(yxxyb)['01010']
     +result2.get_counts(yxxyb)['01100']
     +result2.get_counts(yxxyb)['01111']
     +result2.get_counts(yxxyb)['10001']
     +result2.get_counts(yxxyb)['10010']
     +result2.get_counts(yxxyb)['10100']
     +result2.get_counts(yxxyb)['10111']
     +result2.get_counts(yxxyb)['11000']
     +result2.get_counts(yxxyb)['11011']
     +result2.get_counts(yxxyb)['11101']
     +result2.get_counts(yxxyb)['11110']
       
    -(result2.get_counts(yxxyb)['00001']
     +result2.get_counts(yxxyb)['00010']
     +result2.get_counts(yxxyb)['00100']
     +result2.get_counts(yxxyb)['00111']
     +result2.get_counts(yxxyb)['01000']
     +result2.get_counts(yxxyb)['01011']
     +result2.get_counts(yxxyb)['01101']
     +result2.get_counts(yxxyb)['01110']
     +result2.get_counts(yxxyb)['10000']
     +result2.get_counts(yxxyb)['10011']
     +result2.get_counts(yxxyb)['10101']
     +result2.get_counts(yxxyb)['10110']
     +result2.get_counts(yxxyb)['11001']
     +result2.get_counts(yxxyb)['11010']
     +result2.get_counts(yxxyb)['11100']
     +result2.get_counts(yxxyb)['11111'])
      )/8192)
print(p2)
# Out:
# -0.63916015625

# %%
p3=((result3.get_counts(xxyxa)['00000']
     +result3.get_counts(xxyxa)['00011']
     +result3.get_counts(xxyxa)['00101']
     +result3.get_counts(xxyxa)['00110']
     +result3.get_counts(xxyxa)['01001']
     +result3.get_counts(xxyxa)['01010']
     +result3.get_counts(xxyxa)['01100']
     +result3.get_counts(xxyxa)['01111']
     +result3.get_counts(xxyxa)['10001']
     +result3.get_counts(xxyxa)['10010']
     +result3.get_counts(xxyxa)['10100']
     +result3.get_counts(xxyxa)['10111']
     +result3.get_counts(xxyxa)['11000']
     +result3.get_counts(xxyxa)['11011']
     +result3.get_counts(xxyxa)['11101']
     +result3.get_counts(xxyxa)['11110']
       
    -(result3.get_counts(xxyxa)['00001']
     +result3.get_counts(xxyxa)['00010']
     +result3.get_counts(xxyxa)['00100']
     +result3.get_counts(xxyxa)['00111']
     +result3.get_counts(xxyxa)['01000']
     +result3.get_counts(xxyxa)['01011']
     +result3.get_counts(xxyxa)['01101']
     +result3.get_counts(xxyxa)['01110']
     +result3.get_counts(xxyxa)['10000']
     +result3.get_counts(xxyxa)['10011']
     +result3.get_counts(xxyxa)['10101']
     +result3.get_counts(xxyxa)['10110']
     +result3.get_counts(xxyxa)['11001']
     +result3.get_counts(xxyxa)['11010']
     +result3.get_counts(xxyxa)['11100']
     +result3.get_counts(xxyxa)['11111'])
      )/8192)
print(p3)
# Out:
# -0.581787109375

# %%
p4=((result4.get_counts(xxyxb)['00000']
     +result4.get_counts(xxyxb)['00011']
     +result4.get_counts(xxyxb)['00101']
     +result4.get_counts(xxyxb)['00110']
     +result4.get_counts(xxyxb)['01001']
     +result4.get_counts(xxyxb)['01010']
     +result4.get_counts(xxyxb)['01100']
     +result4.get_counts(xxyxb)['01111']
     +result4.get_counts(xxyxb)['10001']
     +result4.get_counts(xxyxb)['10010']
     +result4.get_counts(xxyxb)['10100']
     +result4.get_counts(xxyxb)['10111']
     +result4.get_counts(xxyxb)['11000']
     +result4.get_counts(xxyxb)['11011']
     +result4.get_counts(xxyxb)['11101']
     +result4.get_counts(xxyxb)['11110']
       
    -(result4.get_counts(xxyxb)['00001']
     +result4.get_counts(xxyxb)['00010']
     +result4.get_counts(xxyxb)['00100']
     +result4.get_counts(xxyxb)['00111']
     +result4.get_counts(xxyxb)['01000']
     +result4.get_counts(xxyxb)['01011']
     +result4.get_counts(xxyxb)['01101']
     +result4.get_counts(xxyxb)['01110']
     +result4.get_counts(xxyxb)['10000']
     +result4.get_counts(xxyxb)['10011']
     +result4.get_counts(xxyxb)['10101']
     +result4.get_counts(xxyxb)['10110']
     +result4.get_counts(xxyxb)['11001']
     +result4.get_counts(xxyxb)['11010']
     +result4.get_counts(xxyxb)['11100']
     +result4.get_counts(xxyxb)['11111'])
      )/8192)
print(p4)
# Out:
# 0.41064453125

# %%
p5=((result5.get_counts(xyxxa)['00000']
     +result5.get_counts(xyxxa)['00011']
     +result5.get_counts(xyxxa)['00101']
     +result5.get_counts(xyxxa)['00110']
     +result5.get_counts(xyxxa)['01001']
     +result5.get_counts(xyxxa)['01010']
     +result5.get_counts(xyxxa)['01100']
     +result5.get_counts(xyxxa)['01111']
     +result5.get_counts(xyxxa)['10001']
     +result5.get_counts(xyxxa)['10010']
     +result5.get_counts(xyxxa)['10100']
     +result5.get_counts(xyxxa)['10111']
     +result5.get_counts(xyxxa)['11000']
     +result5.get_counts(xyxxa)['11011']
     +result5.get_counts(xyxxa)['11101']
     +result5.get_counts(xyxxa)['11110']
       
    -(result5.get_counts(xyxxa)['00001']
     +result5.get_counts(xyxxa)['00010']
     +result5.get_counts(xyxxa)['00100']
     +result5.get_counts(xyxxa)['00111']
     +result5.get_counts(xyxxa)['01000']
     +result5.get_counts(xyxxa)['01011']
     +result5.get_counts(xyxxa)['01101']
     +result5.get_counts(xyxxa)['01110']
     +result5.get_counts(xyxxa)['10000']
     +result5.get_counts(xyxxa)['10011']
     +result5.get_counts(xyxxa)['10101']
     +result5.get_counts(xyxxa)['10110']
     +result5.get_counts(xyxxa)['11001']
     +result5.get_counts(xyxxa)['11010']
     +result5.get_counts(xyxxa)['11100']
     +result5.get_counts(xyxxa)['11111'])
      )/8192)
print(p5)
# Out:
# -0.569580078125

# %%
print(abs(p1)+abs(p2)+abs(p3)+abs(p4)+abs(p5))
# Out:
# 2.52099609375
